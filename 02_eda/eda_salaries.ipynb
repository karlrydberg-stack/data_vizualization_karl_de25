# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\kalle\Documents\Github\data_vizualization_karl_de25\data\salaries.csv')

df.head(3)
# Out:
#    work_year experience_level employment_type      job_title  salary  \
# 0       2024               SE              FT    AI Engineer  202730
# 1       2024               SE              FT    AI Engineer   92118
# 2       2024               SE              FT  Data Engineer  130500
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         202730                 US             0
# 1             USD          92118                 US             0
# 2             USD         130500                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M

# %%
unique_jobs = df['job_title'].nunique()
unique_jobs
# Out:
# 155

# %%
unique_years = df['work_year'].nunique()
unique_years
# Out:
# 5

# %%
unique_countries = df['company_location'].unique()
unique_countries
# Out:
# array(['US', 'AU', 'GB', 'CA', 'NL', 'LT', 'DK', 'FR', 'ZA', 'NZ', 'AR',
#        'ES', 'KE', 'LV', 'IN', 'DE', 'IL', 'FI', 'AT', 'BR', 'CH', 'AE',
#        'PL', 'SA', 'UA', 'EG', 'PH', 'TR', 'OM', 'MX', 'PT', 'BA', 'IT',
#        'AS', 'IE', 'EE', 'MT', 'HU', 'LB', 'RO', 'VN', 'NG', 'LU', 'GI',
#        'CO', 'SI', 'GR', 'MU', 'RU', 'KR', 'CZ', 'QA', 'GH', 'SE', 'AD',
#        'EC', 'NO', 'JP', 'HK', 'CF', 'SG', 'TH', 'HR', 'AM', 'PK', 'IR',
#        'BS', 'PR', 'BE', 'ID', 'MY', 'HN', 'DZ', 'IQ', 'CN', 'CL', 'MD'],
#       dtype=object)

# %%
unique_sizes = df['company_size'].unique()
unique_sizes
# Out:
# array(['M', 'L', 'S'], dtype=object)

# %%
remote = df['remote_ratio'].value_counts(dropna=False)
remote
# Out:
# remote_ratio
# 0      11118
# 100     5167
# 50       249
# Name: count, dtype: int64

# %%
average_salary_per_role = df.groupby('job_title')['salary'].mean(numeric_only=True)
average_salary_per_role
# Out:
# job_title
# AI Architect                       252001.724138
# AI Developer                       134684.210526
# AI Engineer                        163626.866667
# AI Product Manager                 141766.666667
# AI Programmer                      764400.857143
#                                        ...
# Sales Data Analyst                  60000.000000
# Software Data Engineer             120000.000000
# Staff Data Analyst                  84999.333333
# Staff Data Scientist               134500.000000
# Staff Machine Learning Engineer    185000.000000
# Name: salary, Length: 155, dtype: float64

# %%
median_salary_per_role = df.groupby('job_title')['salary'].median(numeric_only=True)
median_salary_per_role
# Out:
# job_title
# AI Architect                       204000.0
# AI Developer                       124000.0
# AI Engineer                        166000.0
# AI Product Manager                 120000.0
# AI Programmer                       70000.0
#                                      ...
# Sales Data Analyst                  60000.0
# Software Data Engineer             100000.0
# Staff Data Analyst                  60000.0
# Staff Data Scientist               134500.0
# Staff Machine Learning Engineer    185000.0
# Name: salary, Length: 155, dtype: float64

# %%
avg_sal_per_seniority = df.groupby('experience_level')['salary'].mean(numeric_only=True)
avg_sal_per_seniority
# Out:
# experience_level
# EN    125831.628679
# EX    208064.343313
# MI    157116.976721
# SE    168852.493440
# Name: salary, dtype: float64

# %%
median_sal_per_seniority = df.groupby('experience_level')['salary'].median(numeric_only=True)
median_sal_per_seniority
# Out:
# experience_level
# EN     84068.0
# EX    194500.0
# MI    115601.0
# SE    155000.0
# Name: salary, dtype: float64

# %%
remote_avg_salary = df.groupby('remote_ratio')['salary'].median(numeric_only=True)
remote_avg_salary
# Out:
# remote_ratio
# 0      143000.0
# 50      85000.0
# 100    141300.0
# Name: salary, dtype: float64

# %%
location_avg_salary = df.groupby('company_location')['salary'].median(numeric_only=True)
location_avg_salary
# Out:
# company_location
# AD     47000.0
# AE     90000.0
# AM     50000.0
# AR     60000.0
# AS     50000.0
#         ...
# TR    103500.0
# UA     84000.0
# US    147500.0
# VN     60000.0
# ZA     44263.0
# Name: salary, Length: 77, dtype: float64
